# %%
#importing neccessery libraries
import pandas as pd
import numpy as np

# %%
#reading and displaying the dataset
diabetes = pd.read_csv('diabetes.csv')
diabetes.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...

# %%
#checking on the type of dataset
type(diabetes)
# Out:
# pandas.core.frame.DataFrame

# %%
#checking the number of rows and columns
diabetes.shape
# Out:
# (520, 17)

# %%
#Checking the data types
diabetes.dtypes
# Out:
# Age                    int64
# Gender                object
# Polyuria              object
# Polydipsia            object
# sudden weight loss    object
# weakness              object
# Polyphagia            object
# Genital thrush        object
# visual blurring       object
# Itching               object
# Irritability          object
# delayed healing       object
# partial paresis       object
# muscle stiffness      object
# Alopecia              object
# Obesity               object
# class                 object
# dtype: object

# %%
#checing if there any missing values presented in the dataset
diabetes.isna().sum()
# Out:
# Age                   0
# Gender                0
# Polyuria              0
# Polydipsia            0
# sudden weight loss    0
# weakness              0
# Polyphagia            0
# Genital thrush        0
# visual blurring       0
# Itching               0
# Irritability          0
# delayed healing       0
# partial paresis       0
# muscle stiffness      0
# Alopecia              0
# Obesity               0
# class                 0
# dtype: int64

# %%
#checking for the unique values in each columns
uniqueValues = diabetes.nunique()
print(uniqueValues)
# Out:
# Age                   51
# Gender                 2
# Polyuria               2
# Polydipsia             2
# sudden weight loss     2
# weakness               2
# Polyphagia             2
# Genital thrush         2
# visual blurring        2
# Itching                2
# Irritability           2
# delayed healing        2
# partial paresis        2
# muscle stiffness       2
# Alopecia               2
# Obesity                2
# class                  2
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
plt.figure(figsize=(8, 6))  
plt.hist(diabetes['Age'], color='lightblue', edgecolor='black')
plt.title('Histogram of Age')  
plt.xlabel('Age')  
plt.ylabel('Frequency')   
plt.show()

# %%
Gender = diabetes['Gender'].value_counts()
Gender.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Gender')
# Out:
# Text(0.5, 1.0, 'Plot of Gender')

# %%
Polyuria = diabetes['Polyuria'].value_counts()
Polyuria.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Polyuria')
# Out:
# Text(0.5, 1.0, 'Plot of Polyuria')

# %%
Polydipsia = diabetes['Polydipsia'].value_counts()
Polydipsia.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Polydipsia')
# Out:
# Text(0.5, 1.0, 'Plot of Polydipsia')

# %%
sudden_weight_loss = diabetes['sudden weight loss'].value_counts()
sudden_weight_loss.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Sudden Weight Loss')
# Out:
# Text(0.5, 1.0, 'Plot of Sudden Weight Loss')

# %%
weakness = diabetes['weakness'].value_counts()
weakness.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Weakness')
# Out:
# Text(0.5, 1.0, 'Plot of Weakness')

# %%
Polyphagia = diabetes['Polyphagia'].value_counts()
Polyphagia.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Polyphagia')
# Out:
# Text(0.5, 1.0, 'Plot of Polyphagia')

# %%
Genital_thrush = diabetes['Genital thrush'].value_counts()
Genital_thrush.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Genital thrush')
# Out:
# Text(0.5, 1.0, 'Plot of Genital thrush')

# %%
visual_blurring = diabetes['visual blurring'].value_counts()
visual_blurring.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Visual Blurring')
# Out:
# Text(0.5, 1.0, 'Plot of Visual Blurring')

# %%
Itching = diabetes['Itching'].value_counts()
Itching.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Itching')
# Out:
# Text(0.5, 1.0, 'Plot of Itching')

# %%
Irritability = diabetes['Irritability'].value_counts()
Irritability.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Irritability')
# Out:
# Text(0.5, 1.0, 'Plot of Irritability')

# %%
delayed_healing = diabetes['delayed healing'].value_counts()
delayed_healing.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Delayed Healing')
# Out:
# Text(0.5, 1.0, 'Plot of Delayed Healing')

# %%
partial_paresis = diabetes['partial paresis'].value_counts()
partial_paresis.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Partial Paresis')
# Out:
# Text(0.5, 1.0, 'Plot of Partial Paresis')

# %%
muscle_stiffness = diabetes['muscle stiffness'].value_counts()
muscle_stiffness.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Muscle Stiffness')
# Out:
# Text(0.5, 1.0, 'Plot of Muscle Stiffness')

# %%
Alopecia = diabetes['Alopecia'].value_counts()
Alopecia.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Alopecia')
# Out:
# Text(0.5, 1.0, 'Plot of Alopecia')

# %%
Obesity = diabetes['Obesity'].value_counts()
Obesity.plot(kind = 'bar', color= ['lightgreen', 'lightblue'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Obesity')
# Out:
# Text(0.5, 1.0, 'Plot of Obesity')

# %%
colors = ['#99ff99','#66b3ff']
diabetes_class = diabetes['class'].value_counts()
diabetes_class.plot(kind = 'pie', figsize = (5,5), colors=colors, autopct='%1.1f%%')
plt.title('Plot of class')
# Out:
# Text(0.5, 1.0, 'Plot of class')

# %% [markdown]
# # Data Pre-processing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
columns = ['Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss', 'weakness', 'Polyphagia', 'Genital thrush', 
           'visual blurring', 'Itching', 'Irritability', 'delayed healing', 'partial paresis', 'muscle stiffness', 
           'Alopecia', 'Obesity', 'class']
label_encoder = LabelEncoder()
for col in columns:
    diabetes[col + '_encoded'] = label_encoder.fit_transform(diabetes[col])
diabetes = diabetes.drop(columns=columns)

# %%
diabetes.head()
# Out:
#    Age  Gender_encoded  Polyuria_encoded  Polydipsia_encoded  \
# 0   40               1                 0                   1
# 1   58               1                 0                   0
# 2   41               1                 1                   0
# 3   45               1                 0                   0
# 4   60               1                 1                   1
#
#    sudden weight loss_encoded  weakness_encoded  Polyphagia_encoded  \
# 0                           0                 1                   0
# 1                           0                 1                   0
# 2                           0                 1                   1
# 3                           1                 1                   1
# 4                           1                 1                   1
#
#    Genital thrush_encoded  visual blurring_encoded  Itching_encoded  \
# 0                       0                        0                1
# ...

# %% [markdown]
# # Modelling

# %%
X = diabetes.drop('class_encoded', axis=1)
Y = diabetes['class_encoded']

# %%
#To balance the imbalanced class
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=123)
Xtrain_balanced, Ytrain_balanced = smote.fit_resample(X, Y)
print("Balanced Xtrain shape:", Xtrain_balanced.shape)
print("Balanced Ytrain shape:", Ytrain_balanced.shape)
# Out:
# Balanced Xtrain shape: (640, 16)
# Balanced Ytrain shape: (640,)

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(Xtrain_balanced, Ytrain_balanced, random_state=123, test_size=0.2)

# %%
Xtrain.shape
# Out:
# (512, 16)

# %%
Xtest.shape
# Out:
# (128, 16)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
Xtrain = scaler.fit_transform(Xtrain)
Xtrain
# Out:
# array([[-0.93381544,  0.69883624, -0.82717019, ..., -0.74264066,
#         -0.76815501, -0.42393809],
#        [-0.69017003, -1.4309504 ,  1.20894105, ..., -0.74264066,
#         -0.76815501, -0.42393809],
#        [ 0.20319646, -1.4309504 ,  1.20894105, ..., -0.74264066,
#         -0.76815501, -0.42393809],
#        ...,
#        [ 1.66506891,  0.69883624,  1.20894105, ..., -0.74264066,
#         -0.76815501, -0.42393809],
#        [-0.20287922, -1.4309504 , -0.82717019, ..., -0.74264066,
#         -0.76815501, -0.42393809],
#        [ 1.58385378,  0.69883624, -0.82717019, ..., -0.74264066,
#          1.30182059, -0.42393809]])

# %%
Xtest = scaler.transform(Xtest)
Xtest
# Out:
# array([[ 0.44684187, -1.4309504 , -0.82717019, ..., -0.74264066,
#         -0.76815501, -0.42393809],
#        [-0.77138517,  0.69883624, -0.82717019, ..., -0.74264066,
#         -0.76815501, -0.42393809],
#        [ 1.34020837,  0.69883624, -0.82717019, ..., -0.74264066,
#         -0.76815501, -0.42393809],
#        ...,
#        [-0.36530949, -1.4309504 ,  1.20894105, ...,  1.34654625,
#         -0.76815501,  2.358835  ],
#        [-0.93381544, -1.4309504 , -0.82717019, ..., -0.74264066,
#         -0.76815501, -0.42393809],
#        [ 1.34020837,  0.69883624, -0.82717019, ...,  1.34654625,
#          1.30182059, -0.42393809]])

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB 
model_NB = GaussianNB()                       
model_NB.fit(Xtrain, Ytrain)                  
NB_model = model_NB.predict(Xtest)

# %%
from sklearn.metrics import accuracy_score
acc_NB = accuracy_score(Ytest, NB_model)
acc_NB
# Out:
# 0.8671875

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, NB_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86        63
#            1       0.85      0.89      0.87        65
#
#     accuracy                           0.87       128
#    macro avg       0.87      0.87      0.87       128
# weighted avg       0.87      0.87      0.87       128

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_NB = confusion_matrix(Ytest, NB_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_NB, display_labels = model_NB.classes_)
disp.plot()

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier 
model_RF = RandomForestClassifier()                       
model_RF.fit(Xtrain, Ytrain)                  
RF_model = model_RF.predict(Xtest)

# %%
acc_RF = accuracy_score(Ytest, RF_model)
acc_RF
# Out:
# 0.9921875

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, RF_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        63
#            1       0.98      1.00      0.99        65
#
#     accuracy                           0.99       128
#    macro avg       0.99      0.99      0.99       128
# weighted avg       0.99      0.99      0.99       128

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_RF = confusion_matrix(Ytest, RF_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_RF, display_labels = model_RF.classes_)
disp.plot()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
model_LR = linear_model.LogisticRegression()
model_LR.fit(Xtrain, Ytrain)
LR_model = model_LR.predict(Xtest)

# %%
acc_LR = accuracy_score(Ytest, LR_model)
acc_LR
# Out:
# 0.9140625

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, LR_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91        63
#            1       0.92      0.91      0.91        65
#
#     accuracy                           0.91       128
#    macro avg       0.91      0.91      0.91       128
# weighted avg       0.91      0.91      0.91       128

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_LR = confusion_matrix(Ytest, LR_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_LR, display_labels = model_LR.classes_)
disp.plot()

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model_DT = DecisionTreeClassifier()
model_DT.fit(Xtrain, Ytrain)
DT_model = model_DT.predict(Xtest)

# %%
acc_DT = accuracy_score(Ytest, DT_model)
acc_DT
# Out:
# 0.96875

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, DT_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97        63
#            1       0.96      0.98      0.97        65
#
#     accuracy                           0.97       128
#    macro avg       0.97      0.97      0.97       128
# weighted avg       0.97      0.97      0.97       128

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_DT = confusion_matrix(Ytest, DT_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_DT, display_labels = model_DT.classes_)
disp.plot()

# %% [markdown]
# ### K-Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier
error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(Xtrain,Ytrain)
 pred_i = knn.predict(Xtest)
 error_rate.append(np.mean(pred_i != Ytest))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
 markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
acc = []
from sklearn import metrics
for i in range(1,40):
    neigh = KNeighborsClassifier(n_neighbors = i).fit(Xtrain,Ytrain)
    yhat = neigh.predict(Xtest)
    acc.append(metrics.accuracy_score(Ytest, yhat))
    
plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color = 'blue',linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
max_accuracy = max(acc)
optimal_k_value = acc.index(max_accuracy) + 1
print("Maximum accuracy:",max_accuracy,"at K =", optimal_k_value)
# Out:
# Maximum accuracy: 0.9609375 at K = 1

# %% [markdown]
# - The optimal k-value is 1 based on the above charts.

# %%
knn = KNeighborsClassifier(n_neighbors=1)
model_KNN = knn.fit(Xtrain, Ytrain)
KNN_model = knn.predict(Xtest)

# %%
acc_KNN = accuracy_score(Ytest, KNN_model)
acc_KNN
# Out:
# 0.9609375

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, KNN_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        63
#            1       0.98      0.94      0.96        65
#
#     accuracy                           0.96       128
#    macro avg       0.96      0.96      0.96       128
# weighted avg       0.96      0.96      0.96       128

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_KNN = confusion_matrix(Ytest, KNN_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_KNN, display_labels = model_KNN.classes_)
disp.plot()

# %% [markdown]
# # Evaluation

# %%
plt.rcParams["figure.figsize"] = [7,7]
acc = [acc_NB, acc_RF, acc_LR, acc_DT, acc_KNN]
models = ['NB', 'RF', 'LR', 'DT', 'KNN']

plt.plot(models,acc, color = 'green', marker = 'o', markerfacecolor = 'red')
plt.grid(False)
plt.show()

# %% [markdown]
# - RF performs best according to the evaluation conducted with an accuracy of 98%
